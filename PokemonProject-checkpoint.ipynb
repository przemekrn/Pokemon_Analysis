# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
pokemon_df = pd.read_csv('./DataSets/Pokemon.csv')
pd.read_csv('./DataSets/Pokemon.csv')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
# Group Pokemon by generation and count the number of Pokemon in each generation
generation_counts = pokemon_df.groupby('Generation')['#'].nunique()

# %%
# Create a bar plot
plt.figure(figsize=(10, 5))
plt.bar(generation_counts.index, generation_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('Generation')
plt.ylabel('Number of New Pokémon')
plt.title('Number of New Pokémon Added by Generation')
plt.xticks(range(1, len(generation_counts) + 1), rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels on top of each bar
for x, y in zip(generation_counts.index, generation_counts.values):
    plt.annotate(f'{y}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center')

plt.ylim(bottom=0)
plt.show()

# %%
# Separate legendary and non-legendary Pokemon
legendary = pokemon_df[pokemon_df['Legendary'] == True]
non_legendary = pokemon_df[pokemon_df['Legendary'] == False]

# %%
# Calculate summary statistics for each group
legendary_stats = legendary[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].describe()
non_legendary_stats = non_legendary[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].describe()

# %%
# Display summary statistics
print('Legendary Pokemon Stats:')
print(legendary_stats)
print('\nNon-Legendary Pokemon Stats:')
print(non_legendary_stats)
# Out:
# Legendary Pokemon Stats:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean    92.738462  116.676923   99.661538  122.184615  105.938462  100.184615
# std     21.722164   30.348037   28.255131   31.104608   28.827004   22.952323
# min     50.000000   50.000000   20.000000   50.000000   20.000000   50.000000
# 25%     80.000000  100.000000   90.000000  100.000000   90.000000   90.000000
# 50%     91.000000  110.000000  100.000000  120.000000  100.000000  100.000000
# 75%    105.000000  131.000000  115.000000  150.000000  120.000000  110.000000
# max    150.000000  190.000000  200.000000  194.000000  200.000000  180.000000
#
# Non-Legendary Pokemon Stats:
#                HP      Attack     Defense     Sp. Atk     Sp. Def       Speed
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean    67.182313   75.669388   71.559184   68.454422   68.892517   65.455782
# std     24.808849   30.490153   30.408194   29.091705   25.669310   27.843038
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   54.500000   50.000000   45.000000   50.000000   45.000000
# 50%     65.000000   72.000000   66.000000   65.000000   65.000000   64.000000
# 75%     79.500000   95.000000   85.000000   85.000000   85.000000   85.000000
# max    255.000000  185.000000  230.000000  175.000000  230.000000  160.000000

# %%
# Create a new column with descriptive labels
pokemon_df['LegendaryLabel'] = pokemon_df['Legendary'].apply(lambda x: 'Legendary' if x else 'Non-Legendary')

# Visualize distributions using box plots
plt.figure(figsize=(12, 8))
plt.subplot(2, 3, 1)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='HP')
plt.subplot(2, 3, 2)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='Attack')
plt.subplot(2, 3, 3)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='Defense')
plt.subplot(2, 3, 4)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='Sp. Atk')
plt.subplot(2, 3, 5)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='Sp. Def')
plt.subplot(2, 3, 6)
sns.boxplot(data=pokemon_df, x='LegendaryLabel', y='Speed')
plt.tight_layout()
plt.show()

# %%
# Create a list of all unique types
all_types = list(set(pokemon_df['Type 1'].tolist() + pokemon_df['Type 2'].dropna().tolist()))
# Create a type advantage matrix
type_advantage = pd.DataFrame(1.0, index=all_types, columns=all_types, dtype=float)
type_effectiveness = {
    'Normal': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 0.5, 'Bug': 1, 'Ghost': 0, 'Steel': 0.5, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 1, 'Dark': 1, 'Fairy': 1},
    'Fighting': {'Normal': 2, 'Fighting': 1, 'Flying': 0.5, 'Poison': 0.5, 'Ground': 1, 'Rock': 2, 'Bug': 0.5, 'Ghost': 0, 'Steel': 2, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 0.5, 'Ice': 2, 'Dragon': 1, 'Dark': 2, 'Fairy': 0.5},
    'Flying': {'Normal': 1, 'Fighting': 2, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 0.5, 'Bug': 2, 'Ghost': 1, 'Steel': 0.5, 'Fire': 1, 'Water': 1, 'Grass': 2, 'Electric': 0.5, 'Psychic': 1, 'Ice': 1, 'Dragon': 1, 'Dark': 1, 'Fairy': 1},
    'Poison': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 0.5, 'Ground': 0.5, 'Rock': 0.5, 'Bug': 1, 'Ghost': 0.5, 'Steel': 0, 'Fire': 1, 'Water': 1, 'Grass': 2, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 1, 'Dark': 1, 'Fairy': 2},
    'Ground': {'Normal': 1, 'Fighting': 1, 'Flying': 0, 'Poison': 2, 'Ground': 1, 'Rock': 2, 'Bug': 0.5, 'Ghost': 1, 'Steel': 2, 'Fire': 2, 'Water': 1, 'Grass': 0.5, 'Electric': 2, 'Psychic': 1, 'Ice': 1, 'Dragon': 1, 'Dark': 1, 'Fairy': 1},
    'Rock': {'Normal': 1, 'Fighting': 0.5, 'Flying': 2, 'Poison': 1, 'Ground': 0.5, 'Rock': 1, 'Bug': 2, 'Ghost': 1, 'Steel': 0.5, 'Fire': 2, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 1, 'Ice': 2, 'Dragon': 1, 'Dark': 1, 'Fairy': 1},
    'Bug': {'Normal': 1, 'Fighting': 0.5, 'Flying': 0.5, 'Poison': 0.5, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 0.5, 'Steel': 0.5, 'Fire': 0.5, 'Water': 1, 'Grass': 2, 'Electric': 1, 'Psychic': 2, 'Ice': 1, 'Dragon': 1, 'Dark': 2, 'Fairy': 0.5},
    'Ghost': {'Normal': 0, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 2, 'Steel': 1, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 2, 'Ice': 1, 'Dragon': 1, 'Dark': 0.5, 'Fairy': 1},
    'Steel': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 2, 'Bug': 1, 'Ghost': 1, 'Steel': 0.5, 'Fire': 0.5, 'Water': 0.5, 'Grass': 1, 'Electric': 0.5, 'Psychic': 1, 'Ice': 2, 'Dragon': 1, 'Dark': 1, 'Fairy': 2},
    'Fire': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 0.5, 'Bug': 2, 'Ghost': 1, 'Steel': 2, 'Fire': 0.5, 'Water': 0.5, 'Grass': 2, 'Electric': 1, 'Psychic': 1, 'Ice': 2, 'Dragon': 0.5, 'Dark': 1, 'Fairy': 1},
    'Water': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 2, 'Rock': 2, 'Bug': 1, 'Ghost': 1, 'Steel': 1, 'Fire': 2, 'Water': 0.5, 'Grass': 0.5, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 0.5, 'Dark': 1, 'Fairy': 1},
    'Grass': {'Normal': 1, 'Fighting': 1, 'Flying': 0.5, 'Poison': 0.5, 'Ground': 2, 'Rock': 2, 'Bug': 0.5, 'Ghost': 1, 'Steel': 0.5, 'Fire': 0.5, 'Water': 2, 'Grass': 0.5, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 0.5, 'Dark': 1, 'Fairy': 1},
    'Electric': {'Normal': 1, 'Fighting': 1, 'Flying': 2, 'Poison': 1, 'Ground': 0, 'Rock': 1, 'Bug': 1, 'Ghost': 1, 'Steel': 1, 'Fire': 1, 'Water': 2, 'Grass': 0.5, 'Electric': 0.5, 'Psychic': 1, 'Ice': 1, 'Dragon': 0.5, 'Dark': 1, 'Fairy': 1},
    'Psychic': {'Normal': 1, 'Fighting': 2, 'Flying': 1, 'Poison': 2, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 1, 'Steel': 0.5, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 0.5, 'Ice': 1, 'Dragon': 1, 'Dark': 0, 'Fairy': 1},
    'Ice': {'Normal': 1, 'Fighting': 1, 'Flying': 2, 'Poison': 1, 'Ground': 2, 'Rock': 1, 'Bug': 1, 'Ghost': 1, 'Steel': 0.5, 'Fire': 0.5, 'Water': 0.5, 'Grass': 2, 'Electric': 1, 'Psychic': 1, 'Ice': 0.5, 'Dragon': 2, 'Dark': 1, 'Fairy': 1},
    'Dragon': {'Normal': 1, 'Fighting': 1, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 1, 'Steel': 0.5, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 2, 'Dark': 1, 'Fairy': 0},
    'Dark': {'Normal': 1, 'Fighting': 0.5, 'Flying': 1, 'Poison': 1, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 2, 'Steel': 1, 'Fire': 1, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 2, 'Ice': 1, 'Dragon': 1, 'Dark': 0.5, 'Fairy': 0.5},
    'Fairy': {'Normal': 1, 'Fighting': 2, 'Flying': 1, 'Poison': 0.5, 'Ground': 1, 'Rock': 1, 'Bug': 1, 'Ghost': 1, 'Steel': 0.5, 'Fire': 0.5, 'Water': 1, 'Grass': 1, 'Electric': 1, 'Psychic': 1, 'Ice': 1, 'Dragon': 2, 'Dark': 2, 'Fairy': 1}
}

# Fill in the type_advantage matrix
for attack_type, defense_types in type_effectiveness.items():
    for defense_type, effectiveness in defense_types.items():
        type_advantage.loc[attack_type, defense_type] = effectiveness

# %%
plt.figure(figsize=(10, 8))
mask = np.tril(type_advantage) == 0
sns.heatmap(type_advantage,cmap='RdYlGn', linewidths=0.5, square=True)
plt.title('Pokemon Type Matchup Chart', fontsize=16)
plt.show()

# %%
# Count the number of Pokemon with each type combination
type_combinations = pokemon_df[['Type 1', 'Type 2']].dropna().apply(tuple, axis=1).value_counts()
sorted_combinations = type_combinations.sort_values(ascending=False)
# Select the top 20 most common type combinations
top_combinations = sorted_combinations.head(10)

# %%
# Create a horizontal bar plot to visualize the most common type combinations
plt.figure(figsize=(10, 6))
top_combinations.plot(kind='barh')
plt.title('Most Common Dual-Type Pokemon Combinations')
plt.xlabel('Count')
plt.tight_layout()
plt.show()
